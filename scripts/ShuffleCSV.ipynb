# %%
import os
import numpy as np
import pandas as pd

df1 = pd.read_csv('trainRecords.csv')
ds1 = df1.sample(frac=1)
ds1.to_csv('trainingRecords.csv')

df2 = pd.read_csv('validateRecords.csv')
ds2 = df2.sample(frac=1)
ds2.to_csv('validationRecords.csv')

# %%
import os
import numpy as np
import pandas as pd

pd.read_csv('trainingRecords.csv')
# Out:
#         Unnamed: 0                                           filename class  \
# 0            82515  /home/chaitanya_anand/Work/TensorFlow/OCR/by_c...     a
# 1            31972  /home/chaitanya_anand/Work/TensorFlow/OCR/by_c...     T
# 2           370877  /home/chaitanya_anand/Work/TensorFlow/OCR/by_c...     6
# 3           473204  /home/chaitanya_anand/Work/TensorFlow/OCR/by_c...     5
# 4           138603  /home/chaitanya_anand/Work/TensorFlow/OCR/by_c...     U
# ...            ...                                                ...   ...
# 588963        1695  /home/chaitanya_anand/Work/TensorFlow/OCR/by_c...     Y
# 588964       29017  /home/chaitanya_anand/Work/TensorFlow/OCR/by_c...     T
# 588965      456478  /home/chaitanya_anand/Work/TensorFlow/OCR/by_c...     5
# 588966      187479  /home/chaitanya_anand/Work/TensorFlow/OCR/by_c...     E
# 588967      322164  /home/chaitanya_anand/Work/TensorFlow/OCR/by_c...     8
#
#         width  height  xmin  ymin  xmax  ymax
# 0         128     128     0     0   128   128
# 1         128     128     0     0   128   128
# 2         128     128     0     0   128   128
# 3         128     128     0     0   128   128
# 4         128     128     0     0   128   128
# ...       ...     ...   ...   ...   ...   ...
# 588963    128     128     0     0   128   128
# 588964    128     128     0     0   128   128
# 588965    128     128     0     0   128   128
# 588966    128     128     0     0   128   128
# 588967    128     128     0     0   128   128
#
# [588968 rows x 9 columns]
