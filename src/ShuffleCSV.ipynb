# %%
import os
import numpy as np
import pandas as pd

df1 = pd.read_csv('trainRecords.csv')
ds1 = df1.sample(frac=1)
ds1.to_csv('trainingRecords.csv')

df2 = pd.read_csv('validateRecords.csv')
ds2 = df2.sample(frac=1)
ds2.to_csv('validationRecords.csv')

# %%
import os
import numpy as np
import pandas as pd

pd.read_csv('trainingRecords.csv')
# Out:
#         Unnamed: 0                                           fileName class
# 0           108697  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     s
# 1            84504  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     m
# 2           101600  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     b
# 3            39051  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     V
# 4            51278  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     K
# ...            ...                                                ...   ...
# 123613       22851  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     P
# 123614       70405  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     W
# 123615       55005  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     4
# 123616       40134  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     o
# 123617       96466  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     J
#
# [123618 rows x 3 columns]
