# %%
import os
import numpy as np
import pandas as pd

df1 = pd.read_csv('trainRecords.csv')
ds1 = df1.sample(frac=1)
ds1.to_csv('trainingRecords.csv')

df2 = pd.read_csv('validateRecords.csv')
ds2 = df2.sample(frac=1)
ds2.to_csv('validationRecords.csv')

# %%
import os
import numpy as np
import pandas as pd

pd.read_csv('trainingRecords.csv')
# Out:
#         Unnamed: 0                                           fileName class
# 0           426073  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     8
# 1           180034  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     l
# 2           115258  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     S
# 3            63081  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     F
# 4           453778  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     e
# ...            ...                                                ...   ...
# 588963      416013  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     8
# 588964      173000  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     T
# 588965      186743  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     l
# 588966      267281  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     R
# 588967      278244  /home/warmach/Desktop/TensorFlow/ocr-keras/New...     0
#
# [588968 rows x 3 columns]
